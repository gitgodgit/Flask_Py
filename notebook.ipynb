# %% [markdown]
# python -m venv .venv

# %% [markdown]
# Set-ExecutionPolicy -ExecutionPolicy RemoteSigned -Scope Process
#
# PS C:\Users\NoeMindilaia\Desktop\Flask_Py> . .venv\Scripts\Activate.ps1
#
# (.venv) PS C:\Users\NoeMindilaia\Desktop\Flask_Py> pip install -r requirements.txt

# %% [markdown]
# from app import db
